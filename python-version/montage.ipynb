# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img1 = cv.imread('../00406.jpg')
img2 = cv.imread('../c0_8.jpg')

plt.subplot(1, 2, 1)
plt.imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))

plt.subplot(1, 2, 2)
plt.imshow(img2, cmap='gray')

plt.show()
