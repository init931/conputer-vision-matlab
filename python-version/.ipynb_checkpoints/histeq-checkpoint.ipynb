# %%
import cv2
from matplotlib import pyplot as plt

# Load the image
image = cv2.imread('../foosballBW.jpg', cv2.IMREAD_GRAYSCALE)  # Load as grayscale

#OpenCV Histogram Equalization
equalized = cv2.equalizeHist(image)

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(equalized, cmap='gray')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

# Load the image
image = cv2.imread('imdata/tire.tif', cv2.IMREAD_GRAYSCALE)  # Load as grayscale

#OpenCV Histogram Equalization
equalized = cv2.equalizeHist(image)

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')

plt.subplot(1, 2, 2)
plt.imshow(equalized, cmap='gray')
plt.show()
